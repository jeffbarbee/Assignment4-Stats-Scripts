# %% [markdown]
# # Assignment 4

# %%
# First Step will be to load the needed packages and data

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 64.5 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 156.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data = pd.read_csv('brain_size.csv',sep=';', na_values=".")
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# ...

# %% [markdown]
# ## Important to Review the data

# %%
list(data.columns)
# Out:
# ['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count']

# %%
# Mean Green box 1; Question 1

# %%
data['VIQ'].mean()
# Out:
# np.float64(112.35)

# %%
grouped_means = data.groupby('Gender')['VIQ'].mean()
grouped_means
# Out:
# Gender
# Female    109.45
# Male      115.25
# Name: VIQ, dtype: float64

# %%
Counts = data.groupby('Gender')['VIQ'].count()
Counts
# Out:
# Gender
# Female    20
# Male      20
# Name: VIQ, dtype: int64

# %%
mri_means = data.groupby('Gender')['MRI_Count'].mean()
mri_means
# Out:
# Gender
# Female    862654.6
# Male      954855.4
# Name: MRI_Count, dtype: float64

# %%
np.log(mri_means)
# Out:
# Gender
# Female    13.667770
# Male      13.769315
# Name: MRI_Count, dtype: float64

# %%
# Correlation Matrix

# %%
from pandas import plotting

pd.plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='MRI_Count', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='MRI_Count', ylabel='Height'>],
#        [<Axes: xlabel='Weight', ylabel='MRI_Count'>,
#         <Axes: xlabel='Height', ylabel='MRI_Count'>,
#         <Axes: xlabel='MRI_Count', ylabel='MRI_Count'>]], dtype=object)

# %% [markdown]
# # Subsetting by Gender

# %%
data_male = data[data['Gender'] == 'Male']

data_female = data[data['Gender'] == 'Female']

# %%
pd.plotting.scatter_matrix(data_male[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='MRI_Count', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='MRI_Count', ylabel='Height'>],
#        [<Axes: xlabel='Weight', ylabel='MRI_Count'>,
#         <Axes: xlabel='Height', ylabel='MRI_Count'>,
#         <Axes: xlabel='MRI_Count', ylabel='MRI_Count'>]], dtype=object)

# %%
pd.plotting.scatter_matrix(data_female[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='MRI_Count', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='MRI_Count', ylabel='Height'>],
#        [<Axes: xlabel='Weight', ylabel='MRI_Count'>,
#         <Axes: xlabel='Height', ylabel='MRI_Count'>,
#         <Axes: xlabel='MRI_Count', ylabel='MRI_Count'>]], dtype=object)

# %%
# T-test for Weight

# %%
pip install scipy
# Out:
# ...
#   Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy import stats

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
stats.ttest_ind(data_male['Weight'], data_female['Weight'])
# Out:
# TtestResult(statistic=np.float64(nan), pvalue=np.float64(nan), df=np.float64(nan))

# %%
 type(data['Weight'])
# Out:
# pandas.core.series.Series
